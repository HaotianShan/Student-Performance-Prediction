# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("/kaggle/input/student-performance-prediction/mat2.csv")
df
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0             0     GP   F   18       U     GT3       A     4     4   at_home
# 1             1     GP   F   17       U     GT3       T     1     1   at_home
# 2             2     GP   F   15       U     LE3       T     1     1   at_home
# 3             3     GP   F   15       U     GT3       T     4     2    health
# 4             4     GP   F   16       U     GT3       T     3     3     other
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390         390     MS   M   20       U     LE3       A     2     2  services
# 391         391     MS   M   17       U     LE3       T     3     1  services
# 392         392     MS   M   21       R     GT3       T     1     1     other
# 393         393     MS   M   18       R     LE3       T     3     2  services
# 394         394     MS   M   19       U     LE3       T     1     1     other
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'school', 'sex', 'age', 'address', 'famsize', 'Pstatus',
#        'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime',
#        'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime',
#        'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0           0     GP   F   18       U     GT3       A     4     4   at_home
# 1           1     GP   F   17       U     GT3       T     1     1   at_home
# 2           2     GP   F   15       U     LE3       T     1     1   at_home
# 3           3     GP   F   15       U     GT3       T     4     2    health
# 4           4     GP   F   16       U     GT3       T     3     3     other
# 5           5     GP   M   16       U     LE3       T     4     3  services
# 6           6     GP   M   16       U     LE3       T     2     2     other
# 7           7     GP   F   17       U     GT3       A     4     4     other
# 8           8     GP   M   15       U     LE3       A     3     2  services
# 9           9     GP   M   15       U     GT3       T     3     4     other
#
#    ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# ...

# %%
df[10:20]
# Out:
#     Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 10          10     GP   F   15       U     GT3       T     4     4   teacher
# 11          11     GP   F   15       U     GT3       T     2     1  services
# 12          12     GP   M   15       U     LE3       T     4     4    health
# 13          13     GP   M   15       U     GT3       T     4     3   teacher
# 14          14     GP   M   15       U     GT3       A     2     2     other
# 15          15     GP   F   16       U     GT3       T     4     4    health
# 16          16     GP   F   16       U     GT3       T     4     4  services
# 17          17     GP   F   16       U     GT3       T     3     3     other
# 18          18     GP   M   17       U     GT3       T     3     2  services
# 19          19     GP   M   16       U     LE3       T     4     3    health
#
#     ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# ...

# %%
df.tail(10)
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 385         385     MS   F   18       R     GT3       T     2     2   at_home
# 386         386     MS   F   18       R     GT3       T     4     4   teacher
# 387         387     MS   F   19       R     GT3       T     2     3  services
# 388         388     MS   F   18       U     LE3       T     3     1   teacher
# 389         389     MS   F   18       U     GT3       T     1     1     other
# 390         390     MS   M   20       U     LE3       A     2     2  services
# 391         391     MS   M   17       U     LE3       T     3     1  services
# 392         392     MS   M   21       R     GT3       T     1     1     other
# 393         393     MS   M   18       R     LE3       T     3     2  services
# 394         394     MS   M   19       U     LE3       T     1     1     other
#
#      ... famrel freetime goout  Dalc  Walc  health absences  G1  G2  G3
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  395 non-null    int64
#  1   school      395 non-null    object
#  2   sex         395 non-null    object
#  3   age         395 non-null    int64
#  4   address     395 non-null    object
#  5   famsize     395 non-null    object
#  6   Pstatus     395 non-null    object
#  7   Medu        395 non-null    int64
#  8   Fedu        395 non-null    int64
#  9   Mjob        395 non-null    object
#  10  Fjob        395 non-null    object
#  11  reason      395 non-null    object
#  12  guardian    395 non-null    object
#  13  traveltime  395 non-null    int64
#  14  studytime   395 non-null    int64
#  15  failures    395 non-null    int64
#  16  schoolsup   395 non-null    object
#  17  famsup      395 non-null    object
#  18  paid        395 non-null    object
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         age        Medu        Fedu  traveltime   studytime  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean   197.000000   16.696203    2.749367    2.521519    1.448101    2.035443
# std    114.170924    1.276043    1.094735    1.088201    0.697505    0.839240
# min      0.000000   15.000000    0.000000    0.000000    1.000000    1.000000
# 25%     98.500000   16.000000    2.000000    2.000000    1.000000    1.000000
# 50%    197.000000   17.000000    3.000000    2.000000    1.000000    2.000000
# 75%    295.500000   18.000000    4.000000    3.000000    2.000000    2.000000
# max    394.000000   22.000000    4.000000    4.000000    4.000000    4.000000
#
#          failures      famrel    freetime       goout        Dalc        Walc  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     0.334177    3.944304    3.235443    3.108861    1.481013    2.291139
# ...

# %%
gtotal=df[df["sex"]=="F"]
gtotal
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 0             0     GP   F   18       U     GT3       A     4     4   at_home
# 1             1     GP   F   17       U     GT3       T     1     1   at_home
# 2             2     GP   F   15       U     LE3       T     1     1   at_home
# 3             3     GP   F   15       U     GT3       T     4     2    health
# 4             4     GP   F   16       U     GT3       T     3     3     other
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 385         385     MS   F   18       R     GT3       T     2     2   at_home
# 386         386     MS   F   18       R     GT3       T     4     4   teacher
# 387         387     MS   F   19       R     GT3       T     2     3  services
# 388         388     MS   F   18       U     LE3       T     3     1   teacher
# 389         389     MS   F   18       U     GT3       T     1     1     other
#
# ...

# %%
btotal=df[df["sex"]=="M"]
btotal
# Out:
#      Unnamed: 0 school sex  age address famsize Pstatus  Medu  Fedu      Mjob  \
# 5             5     GP   M   16       U     LE3       T     4     3  services
# 6             6     GP   M   16       U     LE3       T     2     2     other
# 8             8     GP   M   15       U     LE3       A     3     2  services
# 9             9     GP   M   15       U     GT3       T     3     4     other
# 12           12     GP   M   15       U     LE3       T     4     4    health
# ..          ...    ...  ..  ...     ...     ...     ...   ...   ...       ...
# 390         390     MS   M   20       U     LE3       A     2     2  services
# 391         391     MS   M   17       U     LE3       T     3     1  services
# 392         392     MS   M   21       R     GT3       T     1     1     other
# 393         393     MS   M   18       R     LE3       T     3     2  services
# 394         394     MS   M   19       U     LE3       T     1     1     other
#
# ...

# %%
fig=px.histogram(df,x="sex",
          title="Total no male and female in school",
          width=300,
          height=450)
fig.update_layout(font=dict(size=7))
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.25.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
fig=px.histogram(df,x="famsize",
          title="Family size of the students",
          width=300,
          height=450)
fig.update_layout(font=dict(size=7))
fig.show()
# Out:
# <div>                            <div id="ab30f4ea-f484-4b9b-b64f-cc9ea9e092ac" class="plotly-graph-div" style="height:450px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab30f4ea-f484-4b9b-b64f-cc9ea9e092ac")) {                    Plotly.newPlot(                        "ab30f4ea-f484-4b9b-b64f-cc9ea9e092ac",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"famsize=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["GT3","GT3","LE3","GT3","GT3","LE3","LE3","GT3","LE3","GT3","GT3","GT3","LE3","GT3","GT3","GT3","GT3","GT3","GT3","LE3","GT3","GT3","LE3","LE3","GT3","GT3","GT3","GT3","LE3","GT3","GT3","GT3","
# ...

# %%
job=df[["Fjob","Mjob"]]
job
# Out:
#          Fjob      Mjob
# 0     teacher   at_home
# 1       other   at_home
# 2       other   at_home
# 3    services    health
# 4       other     other
# ..        ...       ...
# 390  services  services
# 391  services  services
# 392     other     other
# 393     other  services
# 394   at_home     other
#
# [395 rows x 2 columns]

# %%
fig=px.histogram(df,x="Fjob",
          title="No. of students mother did occupation and types",
          width=300,
          height=450)
fig.update_layout(font=dict(size=7))
fig.show()
# Out:
# <div>                            <div id="47110316-bb3a-45d4-8677-5f2f8593de08" class="plotly-graph-div" style="height:450px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47110316-bb3a-45d4-8677-5f2f8593de08")) {                    Plotly.newPlot(                        "47110316-bb3a-45d4-8677-5f2f8593de08",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Fjob=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["teacher","other","other","services","other","other","other","teacher","other","other","health","other","services","other","other","other","services","other","services","other","other","health","o
# ...

# %%
fx=px.histogram(df,x="Fjob",
               title="No. of students Father did occupation and types",
               width=300,
               height=500)
fx.update_layout(font=dict(size=8))
fx.show()
# Out:
# <div>                            <div id="bd7252ea-e3a9-4306-86ee-0f20a259c2bd" class="plotly-graph-div" style="height:500px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bd7252ea-e3a9-4306-86ee-0f20a259c2bd")) {                    Plotly.newPlot(                        "bd7252ea-e3a9-4306-86ee-0f20a259c2bd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Fjob=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["teacher","other","other","services","other","other","other","teacher","other","other","health","other","services","other","other","other","services","other","services","other","other","health","o
# ...

# %%
fig=px.histogram(df,x=["Fjob","Mjob"],
             title="Parents occupation",
             width=300,height=450)
fig.update_layout(font=dict(size=9))
fig.show()
# Out:
# <div>                            <div id="e18a8987-0904-4eea-9266-55a9d29b8afc" class="plotly-graph-div" style="height:450px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e18a8987-0904-4eea-9266-55a9d29b8afc")) {                    Plotly.newPlot(                        "e18a8987-0904-4eea-9266-55a9d29b8afc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=Fjob\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fjob","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Fjob","offsetgroup":"Fjob","orientation":"v","showlegend":true,"x":["teacher","other","other","services","other","other","other","teacher","other","other","health","other","services","other","other","other","services","other"
# ...

# %%
fig=px.histogram(df,x="absences",
                title="Absences of students",
                width=300,
                height=450)
fig.update_layout(font=dict(size=9))
fig.show()
# Out:
# <div>                            <div id="5296771a-0341-45ca-be6f-558c90a21d29" class="plotly-graph-div" style="height:450px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5296771a-0341-45ca-be6f-558c90a21d29")) {                    Plotly.newPlot(                        "5296771a-0341-45ca-be6f-558c90a21d29",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"absences=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[6,4,10,2,4,10,0,6,0,0,0,4,2,2,0,4,6,4,16,4,0,0,2,0,2,14,2,4,4,16,0,0,0,0,0,0,2,7,2,8,25,8,2,0,14,8,12,4,2,2,2,2,6,0,6,8,0,4,2,2,6,6,4,2,0,2,4,4,2,12,0,0,2,2,54,6,8,0,2,12,2,4,10,4,2,6,4,4,12,1
# ...

# %%
df["guardian"]
# Out:
# 0      mother
# 1      father
# 2      mother
# 3      mother
# 4      father
#         ...
# 390     other
# 391    mother
# 392     other
# 393    mother
# 394    father
# Name: guardian, Length: 395, dtype: object

# %%
fig=px.histogram(df,x="guardian",
                title="Students guardian",
                width=300,
                height=450)
fig.update_layout(font=dict(size=9))
fig.show()
# Out:
# <div>                            <div id="08f9be2c-1173-40b5-a65c-1213fc16eeb3" class="plotly-graph-div" style="height:450px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("08f9be2c-1173-40b5-a65c-1213fc16eeb3")) {                    Plotly.newPlot(                        "08f9be2c-1173-40b5-a65c-1213fc16eeb3",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"guardian=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["mother","father","mother","mother","father","mother","mother","mother","mother","mother","mother","father","father","mother","other","mother","mother","mother","mother","father","mother","fat
# ...

# %%
fig=px.histogram(df,x=["G1","G2","G3"],
                title="Grades",
                width=300,
                height=450)
fig.update_layout(font=dict(size=9))
# Out:
# <div>                            <div id="d47dff7f-9331-43bc-999e-a3d71f511673" class="plotly-graph-div" style="height:450px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d47dff7f-9331-43bc-999e-a3d71f511673")) {                    Plotly.newPlot(                        "d47dff7f-9331-43bc-999e-a3d71f511673",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=G1\u003cbr\u003evalue=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"G1","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"G1","offsetgroup":"G1","orientation":"v","showlegend":true,"x":[5,5,7,15,6,15,12,6,16,14,10,10,14,10,14,14,13,8,6,8,13,12,15,13,10,6,12,15,11,10,9,17,17,8,12,8,15,15,12,14,7,12,19,8,10,8,11,19,15,7,12,11,11,8,10,8,14,14,9,15,10,1
# ...

# %%
plt.figure(figsize=(10,6))
plt.title("Grades of student")
sns.barplot(data=df,x="G1")
# Out:
# <Axes: title={'center': 'Grades of student'}, xlabel='G1'>

# %%
fig=px.histogram(df,x="age",
                title="Age of  students",
                width=300,
                height=450)
fig.update_layout(font=dict(size=9))
fig.show()
# Out:
# <div>                            <div id="4b3e4efb-0ed1-43f5-8036-51008e30d85d" class="plotly-graph-div" style="height:450px; width:300px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b3e4efb-0ed1-43f5-8036-51008e30d85d")) {                    Plotly.newPlot(                        "4b3e4efb-0ed1-43f5-8036-51008e30d85d",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[18,17,15,15,16,16,16,17,15,15,15,15,15,15,15,16,16,16,17,16,15,15,16,16,15,16,15,15,16,16,15,15,15,15,16,15,15,16,15,15,16,15,15,15,16,15,16,16,15,15,16,15,15,15,15,16,15,15,15,16,16,16,16,16,15,16
# ...

# %%
sns.regplot(x=df["Dalc"],y=df["Walc"])
# Out:
# <Axes: xlabel='Dalc', ylabel='Walc'>
